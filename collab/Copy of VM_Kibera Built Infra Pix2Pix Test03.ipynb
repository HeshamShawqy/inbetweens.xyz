# %% [markdown]
# **ATTEMPT 3**
#
# This is the third test at creating data.
#
# How much difference does a larger dataset creat?.
#
# By splitting the main map images (of size (8192x5990pixels) into a 27x21 grid *(as opposed to the 19x14 grid used earlier)*. This gives us 567 images of size 365x 343pixels each.
#
# We rotatet the iamges by 180degrees and also mirror them on the horizontal and vertical axis to creake a dataset 4 times larger of its base.
#
# Post cleaning the dataset, we end up wit 1596 images which is 7.7 times the size of the dataset used in Attemot 02.
#
# The sole intent of this process, is to understand how much of a difference would a larger dataset create in the final results.

# %%
# %tensorflow_version 1.x

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)

# %%
import os
from google.colab import drive

mountpoint= '/content/drive'
drive.mount(mountpoint)

# %%
# !git clone https://github.com/affinelayer/pix2pix-tensorflow.git

# %%
#attach "TRAIN" file here, along with the output directory
# and add the Epochs, and play with with other hyper parameters

# !python pix2pix-tensorflow/pix2pix.py --mode train --output_dir K04_train --max_epochs 160 --input_dir /content/drive/MyDrive/ColabNotebooks/GEN/GEN_Datasets/K04/train

# %%
#attach validation folder here, also keep an eye on the output directory and the checkpoint
#------? can we attach test here, try it out maybe

# !python pix2pix-tensorflow/pix2pix.py --mode test --output_dir K04_test --input_dir /content/drive/MyDrive/ColabNotebooks/GEN/GEN_Datasets/K04/val --checkpoint K04_train

# %%
#To visualise data
#change file name

# %reload_ext tensorboard
# %tensorboard --logdir=K04_train

# %%
#change file names as required

from IPython.display import Image, display
display(Image('/content/K04_test/images/10-inputs.png'))
display(Image('/content/K04_test/images/10-outputs.png'))
display(Image('/content/K04_test/images/10-targets.png'))

# %%
#to download the file
# !zip -r /content/K04_test.zip /content/K04_test

# %%
#download the final set

from google.colab import files
files.download("/content/K04_test.zip")
